# %% [markdown]
# #### Pavlo Yatluk
# #### dz_65

# %% [markdown]
# ### ЗАВДАННЯ

# %% [markdown]
# #### Завантажте зображення titanic.jpg, що знаходиться в репозиторії лекції. Застосуйте до нього методи детекції облич Віоли-Джонса та HOG. Оформіть результати детекції в середовищі Jupyter Notebook

# %%
# встановлення бібліотеки 
pip install dlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\pavel\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\pavel\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\pavel\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\pavel\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\pavel\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\pavel\appdata\local\programs\python\python310\lib\site-packages)

# %%
pip install imutils
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\pavel\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\pavel\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\pavel\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\pavel\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\pavel\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\pavel\appdata\local\programs\python\python310\lib\site-packages)

# %%
# імпорт бібліотек
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
# загрузка класифікатора обличчя
face_cascade = cv2.CascadeClassifier(r"C:\Users\Pavel\Documents\GitHub\PDS1\Lesson 64\haarcascade_frontalface_default.xml")

# %% [markdown]
# ### Метод детекції обличчя Віоли-Джонса

# %%
# загрузка зображення та його візуалізація
img = cv2.imread(r"C:\Users\Pavel\Documents\GitHub\PDS1\Lesson 64\titanic.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.axis('off')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# застосування метода детекції Віли-Джонса
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 5)
plt.imshow(img)
face_detect = dlib.get_frontal_face_detector()
rects = face_detect(gray, 1)

for (i, rect) in enumerate(rects):
    (x, y, w, h) = face_utils.rect_to_bb(rect)
    cv2.rectangle(gray, (x, y), (x + w, y + h), (255, 255, 255), 3)
    
plt.figure(figsize=(10,6))
plt.imshow(gray, cmap='gray')
plt.axis('off')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Метод детекції обличчя HOG

# %%
# імпорт бібліотек
import dlib
from imutils import face_utils

# %%
gray = cv2.imread(r"C:\Users\Pavel\Documents\GitHub\PDS1\Lesson 64\titanic.jpg", 0)
im = np.float32(gray) / 255.0
# Computing gradients
gx = cv2.Sobel(im, cv2.CV_32F, 1, 0, ksize=1)
gy = cv2.Sobel(im, cv2.CV_32F, 0, 1, ksize=1)
mag, angle = cv2.cartToPolar(gx, gy, angleInDegrees=True)

# %%
plt.imshow(mag)
plt.axis('off')
plt.show()

# %%
face_detect = dlib.get_frontal_face_detector()
rects = face_detect(gray, 1)

for (i, rect) in enumerate(rects):
    (x, y, w, h) = face_utils.rect_to_bb(rect)
    cv2.rectangle(gray, (x, y), (x + w, y + h), (255, 255, 255), 3)
    
plt.figure(figsize=(10,6))
plt.imshow(gray, cmap='gray')
plt.axis('off')
plt.show()
